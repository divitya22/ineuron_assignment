# %% [markdown]
# ##### Q1
#
# What will the output be of ((500//7) % 5) ** 3?

# %%
((500//7)%5)**3
# Out:
# 1

# %% [markdown]
# ##### Q2
#
# How will you extract ‘love’ from the string S = “I love Python”? (More than one option may be correct.).

# %%
S="I love python"

# %%
print(S[2:6])
# Out:
# love

# %% [markdown]
# ##### Q3
#
# What will the output of 3 * 3 ** 3 be?

# %%
3*3**3
# Out:
# 81

# %% [markdown]
# ##### Q4
#
# If you have a tuple T = (3, 5, 7, 11), what will the output of T.append(9) be?

# %%
T=(3,5,7,11). # error because tuples are immutable

# %%
print(T.append(9))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-22b56a5323f2> in <module>()
# ----> 1 print(T.append(9))
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ##### Q5
#
# What will the output of the following program be?
#
# L1 = ['Vikas', 'Akshay', 'Sanskar', 'Mahima']
#
# print(L1[1][-1])

# %%
L1 = ['Vikas', 'Akshay', 'Sanskar', 'Mahima']

# %%
print(L1[1][-1])
# Out:
# y

# %% [markdown]
# ##### Q6
#
# What will be the output ?
#
# l = [32, 34, 12, 27, 33]
#
# l.append([14, 19])
#
# print(len(l))

# %%
l = [32, 34, 12, 27, 33]
l.append([14, 19])
print(len(l))
# Out:
# 6
